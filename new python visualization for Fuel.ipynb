# %% [markdown]
# # Data Cleaning
# # Python Project - Data Cleaning And Visualization of Cars Data
# ## by Asare Samuel
#
# ## Introduction
# > ### The cars dataset compiles information on different models of cars.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('fuel.csv')

# %%
df
# Out:
#          id        make             model  year           VClass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fuelType  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
df.columns.str.lower()
# Out:
# Index(['id', 'make', 'model', 'year', 'vclass', 'drive', 'trans', 'fueltype',
#        'cylinders', 'displacement', 'combined fuel efficiency',
#        'co2 emission'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
df.trans.str.split('(',expand=True)[0]
# Out:
# 0       Automatic
# 1       Automatic
# 2       Automatic
# 3       Automatic
# 4       Automatic
#            ...
# 3924    Automatic
# 3925    Automatic
# 3926    Automatic
# 3927    Automatic
# 3928    Automatic
# Name: 0, Length: 3929, dtype: object

# %%
df.trans=df.trans.str.split('(',expand=True)[0]

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive       trans          fueltype  cylinders  \
# 0       All-Wheel Drive  Automatic   Premium Gasoline          6
# ...

# %%
df.rename(columns={"trans":"transmission"}, inplace=True)

# %%
df.rename(columns={"fueltype":"fuel_type","combined fuel efficiency":"combined_fuel_efficiency","co2 emission":"co2_emission"}, inplace=True)

# %%
df.head(2)
# Out:
#       id        make model  year           vclass              drive  \
# 0  32204      Nissan  GT-R  2013  Subcompact Cars    All-Wheel Drive
# 1  32205  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
#
#   transmission         fuel_type  cylinders  displacement  \
# 0   Automatic   Premium Gasoline          6           3.8
# 1   Automatic   Premium Gasoline          4           2.0
#
#    combined_fuel_efficiency  co2_emission
# 0                   18.7389           471
# 1                   25.2227           349

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3929 non-null   int64
#  1   make                      3929 non-null   object
#  2   model                     3929 non-null   object
#  3   year                      3929 non-null   int64
#  4   vclass                    3929 non-null   object
#  5   drive                     3929 non-null   object
#  6   transmission              3929 non-null   object
#  7   fuel_type                 3929 non-null   object
#  8   cylinders                 3929 non-null   int64
#  9   displacement              3929 non-null   float64
#  10  combined_fuel_efficiency  3929 non-null   float64
#  11  co2_emission              3929 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 368.5+ KB

# %%
df.describe()
# Out:
#                  id         year    cylinders  displacement  \
# count   3929.000000  3929.000000  3929.000000   3929.000000
# mean   36006.724357  2015.500891     5.468313      2.950573
# std     2189.349923     1.694775     1.878319      1.305901
# min    32204.000000  2013.000000     2.000000      0.600000
# 25%    34087.000000  2014.000000     4.000000      2.000000
# 50%    36020.000000  2015.000000     5.000000      2.500000
# 75%    37935.000000  2017.000000     6.000000      3.600000
# max    39901.000000  2018.000000    12.000000      7.000000
#
#        combined_fuel_efficiency  co2_emission
# count               3929.000000   3929.000000
# mean                  24.791339    376.564266
# std                    6.003246     92.338892
# min                   12.821700     29.000000
# 25%                   20.658100    315.000000
# 50%                   24.000000    369.000000
# 75%                   28.227100    429.000000
# max                   57.782400    692.000000

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ###   Univariate Visualization

# %% [markdown]
# 1. #### Categorical Variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3929 non-null   int64
#  1   make                      3929 non-null   object
#  2   model                     3929 non-null   object
#  3   year                      3929 non-null   int64
#  4   vclass                    3929 non-null   object
#  5   drive                     3929 non-null   object
#  6   transmission              3929 non-null   object
#  7   fuel_type                 3929 non-null   object
#  8   cylinders                 3929 non-null   int64
#  9   displacement              3929 non-null   float64
#  10  combined_fuel_efficiency  3929 non-null   float64
#  11  co2_emission              3929 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 368.5+ KB

# %%
df.head()
# Out:
#       id        make           model  year           vclass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive transmission         fuel_type  cylinders  displacement  \
# 0    All-Wheel Drive   Automatic   Premium Gasoline          6           3.8
# 1  Front-Wheel Drive   Automatic   Premium Gasoline          4           2.0
# 2  Front-Wheel Drive   Automatic   Premium Gasoline          6           3.6
# 3    All-Wheel Drive   Automatic   Premium Gasoline          6           3.6
# 4  Front-Wheel Drive   Automatic   Regular Gasoline          4           2.4
#
#    combined_fuel_efficiency  co2_emission
# 0                   18.7389           471
# 1                   25.2227           349
# ...

# %% [markdown]
# make= Categorical
# model= Categorical
# year= Categorical
# drive= Categorical
# transmission= Categorical
# fuel_type = Categorical
# cylinders= Categorical
# displacement= Quantitative
# combined_fuel_efficiency= Quantitative
# co2_emission = quantitative

# %%
df.transmission.value_counts()
# Out:
# Automatic          2472
# Manual 6-spd        658
# Automatic 7-spd     212
# Automatic 8-spd     138
# Automatic 6-spd     126
# Manual 5-spd        126
# Manual 7-spd         77
# Automatic 9-spd      62
# Automatic 5-spd      33
# Automatic 4-spd      25
# Name: transmission, dtype: int64

# %%
sns.countplot(data=df, y='transmission', color=sns.color_palette()[4]);
plt.title('Count of Transmission Types');

# %%
sns.countplot(data=df, y='make', color=sns.color_palette()[4]);
plt.title('Count of Vehicle Makes');

# %%
sns.countplot(data=df, x='fuel_type', color=sns.color_palette()[4]);
plt.title('Count of Fuel Types');

# %%
sns.countplot(data=df, x='cylinders', color=sns.color_palette()[4]);
plt.title('Count of Cylinders');

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive transmission         fuel_type  cylinders  \
# 0       All-Wheel Drive   Automatic   Premium Gasoline          6
# ...

# %%
df.fuel_type.value_counts()
# Out:
# Premium Gasoline     2302
# Regular Gasoline     1521
# Diesel                 80
# Midgrade Gasoline      23
# Natural Gas             3
# Name: fuel_type, dtype: int64

# %%
plt.pie(df.fuel_type.value_counts(), labels=df.fuel_type.value_counts().index);
plt.title('Distribution of Fuel Types');

# %% [markdown]
# 2. #### Quantitative Variables

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive transmission         fuel_type  cylinders  \
# 0       All-Wheel Drive   Automatic   Premium Gasoline          6
# ...

# %%
plt.hist(data=df, x='displacement');
plt.title('Displacement');

# %%
plt.hist(data=df, x='combined_fuel_efficiency');
plt.title('Combined Fuel Efficiency');

# %%
plt.hist(data=df, x='co2_emission');
plt.title('Co2 Emissions');

# %% [markdown]
# ### Bivariate Visualization

# %% [markdown]
# #### 1. Two Quantitative Variables

# %%
plt.scatter(data=df, x='combined_fuel_efficiency', y='displacement');
plt.title('Correlation Map:Fuel Efficiency and Displacement');

# %%
plt.scatter(data=df, x='combined_fuel_efficiency', y='co2_emission');
plt.title('Correlation Map:Fuel Efficiency and Co2 Emissions');

# %%
plt.scatter(data=df, x='displacement', y='co2_emission');
plt.title('Correlation Map:Displacement and Co2 Emissions');

# %% [markdown]
# #### 2. Two Categorical Variables

# %% [markdown]
# make= Categorical
# model= Categorical
# year= Categorical
# drive= Categorical
# transmission= Categorical
# fuel_type = Categorical
# cylinders= Categorical
# displacement= Quantitative
# combined_fuel_efficiency= Quantitative
# co2_emission = quantitative

# %%
sns.countplot(data=df, x='year', hue='drive');
plt.title('Year By Type of Vehicle Drive');

# %%
sns.countplot(data=df, x='year', hue='transmission');
plt.title('Year By Type of Vehicle Transmission');

# %% [markdown]
# #### 3. One Quantitative, One Categorical

# %%
sns.boxplot(data=df, x='transmission',y='displacement');
plt.title('Transmission By Displacement');

# %%
sns.boxplot(data=df, x='fuel_type',y='co2_emission');
plt.title('Fuel Type By Co2 Emission');

# %%
sns.boxplot(data=df, x='cylinders',y='combined_fuel_efficiency');
plt.title('Number of Cylinders By Fuel Efficiency');

# %%
df.to_csv('new python visualization for Fuel')
